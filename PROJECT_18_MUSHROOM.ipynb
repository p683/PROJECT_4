# %%
# IMPORTING THE DATASET
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# IMPORTING THE DATASET
data = pd.read_csv("C:\\Users\\PUNEET SINGH\\mushrooms.csv")
data.shape
# Out:
# (8124, 23)

# %%
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
# CHECKING FOR THE NULL VALUES IN A DATASET
data.isnull().sum().any()
# Out:
# False

# %%
# HEAT MAP FOR THE NULL VALUES OF THE DATASET
f,ax = plt.subplots(figsize=(10,8))
sns.heatmap(data.isnull())

# %%
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
data = pd.DataFrame(data)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# class                       8124 non-null object
# cap-shape                   8124 non-null object
# cap-surface                 8124 non-null object
# cap-color                   8124 non-null object
# bruises                     8124 non-null object
# odor                        8124 non-null object
# gill-attachment             8124 non-null object
# gill-spacing                8124 non-null object
# gill-size                   8124 non-null object
# gill-color                  8124 non-null object
# stalk-shape                 8124 non-null object
# stalk-root                  8124 non-null object
# stalk-surface-above-ring    8124 non-null object
# stalk-surface-below-ring    8124 non-null object
# stalk-color-above-ring      8124 non-null object
# stalk-color-below-ring      8124 non-null object
# veil-type                   8124 non-null object
# ...

# %%
# SUMMARY OF THE DATASET
data.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
data['class'].value_counts(normalize=True)
# Out:
# e    0.517971
# p    0.482029
# Name: class, dtype: float64

# %%
ax = sns.countplot(x="class", data=data) 
#balanced dataset

# %%
ax = sns.countplot(x="class", hue="population", data=data)

# %%
# CONVERTING ALL THE CATEGORICAL DATA INTO BINARY FORM THROUGH LABEL ENCODER
# IMPORTING THE LIBRARY
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for col in data.columns:
    data[col] = labelencoder.fit_transform(data[col])

# %%
# CHECKING THE DATA 
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
# VISUALISING THE RELATION PLOT BETWEEN THE TARGET VARIABLE AND CAP-SHAPE VARIABLE
sns.set(style='darkgrid')
sns.relplot(x='class',y='cap-shape',hue='odor',data=data)

# %%
# CHECKING THE LINEAR RELATION BETWEEN THE TARGET VARIABLE AND FEATURE
sns.lmplot(x='class',y='ring-type',hue='gill-color',data=data)

# %%
# NO RELATION WITH TARGET VARIABLE AS SUCH

# %%
sns.lmplot(x='class',y='ring-type',hue='gill-size',data=data)

# %%
# CORRELATION BETWEEN THE TARGET VARIABLE AND FEATURES OF THE DATASET THROUGH HEATMAP
corr_heatmap = data.corr()
f,ax = plt.subplots(figsize=(20,15))
sns.heatmap(corr_heatmap,annot=True,square=True)

# %%
# bruises,gill-color,ring-type ARE NEGATIVELY CORRELATED WITH THE TARGET VARIBALE

# %%
# gill-size,population ARE POSITIVELY RELATED WITH THE TARGET VARIABLE

# %%
# veil-color has no effect on anyone i.e it has to be dropped.

# %%
data.drop(['bruises','gill-color','ring-type','veil-color'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (8124, 19)

# %%
# DIVIDING THE DATA INTO INDEPENDENT AND DEPENDENT VARIABLES
x = data.drop(['class'],axis=1)
y = data['class']
# X == INDEPENDENT AND Y == DEPENDENT

# %%
# SPLITTING THE DATASET THROUGH CROSS_VAL_SCORE
# IMPORTING THE LIBRARY
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# %%
# APPLYING BAGGING AND BOOSTING BOTH TYPE OF MODELS

# %%
# BAGGING MODEL
# IMPORTING THE LIBRARIES
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
rf = RandomForestClassifier(n_estimators=20,criterion='entropy',max_depth=5)
dtc = DecisionTreeClassifier(criterion='entropy',max_depth=5)

# %%
score = cross_val_score(rf,x,y,cv=7,scoring='accuracy').mean()*100

# %%
score
# Out:
# 94.722291800643

# %%
y_pred = cross_val_predict(rf,x,y,cv=7)

# %%
# SCORE METRICS FOR THE METRICS
# IMPORTING THE LIBRARIES
from sklearn.metrics import confusion_matrix,roc_auc_score,accuracy_score

# %%
matrix = confusion_matrix(y_pred,y)
matrix
# Out:
# array([[4202,  333],
#        [   6, 3583]], dtype=int64)

# %%
score = accuracy_score(y_pred,y)*100
score
# Out:
# 95.8271787296898

# %%
roc_score = roc_auc_score(y_pred,y)
roc_score
# Out:
# 0.9624496693467698

# %%
############ RANDOM FOREST IS PREDICTING VERY GOOD #########

# %%
# decision tree
score = cross_val_score(dtc,x,y,cv=7,scoring='accuracy').mean()*100
score
# Out:
# 91.2000076308047

# %%
pred = cross_val_predict(dtc,x,y,cv=7)

# %%
matrix = confusion_matrix(pred,y)
matrix
# Out:
# array([[3756,  263],
#        [ 452, 3653]], dtype=int64)

# %%
# CLEARLY IT DEPICTS THAT DECISION TREE HAS PREDICTED LESS FALSE NEGATIVE RATE

# %%
roc_score = roc_auc_score(pred,y)
roc_score
# Out:
# 0.9122256068085848

# %%
######### BOOSTING MODELS ##############
# IMPORTING THE LIBRARIES
from sklearn.ensemble import AdaBoostClassifier

# %%
boost = AdaBoostClassifier(n_estimators=50)

# %%
score = cross_val_score(boost,x,y,cv=7,scoring='accuracy').mean()*100
score
# Out:
# 92.34532782784905

# %%
pred = cross_val_predict(boost,x,y,cv=7)

# %%
matrix = confusion_matrix(pred,y)
matrix
# Out:
# array([[3842,  256],
#        [ 366, 3660]], dtype=int64)

# %%
# FALSE NEGATIVE RATE ARE LESS THAN BOTH THE MODELS

# %%
roc_score = roc_auc_score(pred,y)
roc_score
# Out:
# 0.9233107058875727

# %%
# BASED ON ACCURACY SCORE OF THE MODEL AND FALSE NEGATIVE RATE 
# DECISION TREE IS PREDICTING THE BEST
